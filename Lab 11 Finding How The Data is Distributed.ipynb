# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 159.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 181.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 147.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 145.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 130.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Display the first few rows of the dataset
df.head(7)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2                     I am a developer by profession
# 2           3                     I am a developer by profession
# 3           4                              I am learning to code
# 4           5                     I am a developer by profession
# 5           6                        I code primarily as a hobby
# 6           7  I am not primarily a developer, but I write co...
#
#                   Age           Employment RemoteWork   Check  \
# 0  Under 18 years old  Employed, full-time     Remote  Apples
# 1     35-44 years old  Employed, full-time     Remote  Apples
# 2     45-54 years old  Employed, full-time     Remote  Apples
# 3     18-24 years old   Student, full-time        NaN  Apples
# 4     18-24 years old   Student, full-time        NaN  Apples
# 5  Under 18 years old   Student, full-time        NaN  Apples
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
## Write your code here
df.columns
df.dtypes
df.describe()
df.shape
# Out:
# (65437, 114)

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
## Write your code here
df.isnull().sum().to_dict()
# Out:
# {'ResponseId': 0,
#  'MainBranch': 0,
#  'Age': 0,
#  'Employment': 0,
#  'RemoteWork': 10631,
#  'Check': 0,
#  'CodingActivities': 10971,
#  'EdLevel': 4653,
#  'LearnCode': 4949,
#  'LearnCodeOnline': 16200,
#  'TechDoc': 24540,
#  'YearsCode': 5568,
#  'YearsCodePro': 13827,
#  'DevType': 5992,
#  'OrgSize': 17957,
#  'PurchaseInfluence': 18031,
#  'BuyNewTool': 20256,
#  'BuildvsBuy': 22079,
#  'TechEndorse': 21769,
#  'Country': 6507,
#  'Currency': 18753,
#  'CompTotal': 31697,
#  'LanguageHaveWorkedWith': 5692,
#  'LanguageWantToWorkWith': 9685,
#  'LanguageAdmired': 14565,
#  'DatabaseHaveWorkedWith': 15183,
#  'DatabaseWantToWorkWith': 22879,
#  'DatabaseAdmired': 26880,
#  'PlatformHaveWorkedWith': 23071,
#  'PlatformWantToWorkWith': 30905,
#  'PlatformAdmired': 34060,
#  'WebframeHaveWorkedWith': 20276,
#  'WebframeWantToWorkWith': 26902,
#  'WebframeAdmired': 30494,
#  'EmbeddedHaveWorkedWith': 43223,
#  'EmbeddedWantToWorkWith': 47837,
#  'EmbeddedAdmired': 48704,
# ...

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
## Write your code here
df['Employment'].value_counts()
df['JobSat'].value_counts()
#df['YearsCodePro'].value_counts()
# Out:
# JobSat
# 8.0     7509
# 7.0     6379
# 6.0     3751
# 9.0     3626
# 10.0    2251
# 5.0     1956
# 3.0     1165
# 4.0     1130
# 2.0      772
# 0.0      311
# 1.0      276
# Name: count, dtype: int64

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
## Write your code here
sns.kdeplot(data=df, x='JobSat', fill=True)
plt.title('Distribution of Job Satisfaction')
plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
## Write your code here
freq_language_workedwith = df['LanguageHaveWorkedWith'].str.split(';').explode().value_counts()
freq_language_want_to_work_with= df['LanguageWantToWorkWith'].str.split(';').explode().value_counts()
df_lang= pd.DataFrame({'workedwith': freq_language_workedwith, 'want to work with': freq_language_want_to_work_with}).reset_index()
df_lang =df_lang.rename(columns={'index': 'Language'})
df_melted= df_lang.melt(id_vars= 'Language', var_name= 'Category', value_name= 'Count') 

plt.figure(figsize=(15,10))
sns.barplot(data=df_melted, x='Language', y='Count', hue='Category')
plt.title('Comaprison of Frequency for LanguageHaveWorkedWith and LanguageWantToWorkWith') 
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
## Write your code here
df1= pd.crosstab(df['Country'], df['RemoteWork']).reset_index().dropna()
df1_melted = df1.melt(id_vars= 'Country', var_name= 'RemoteWork category', value_name= 'Count').dropna()

plt.figure(figsize=(10,25))
sns.barplot(data=df1_melted, x='Count', y='Country', hue='RemoteWork category')
plt.xticks(rotation=90)
plt.show()
# Out:
# RemoteWork                               Country  \
# 172         Venezuela, Bolivarian Republic of...
# 173                                     Viet Nam
# 174                                        Yemen
# 175                                       Zambia
# 176                                     Zimbabwe
#
# RemoteWork  Hybrid (some remote, some in-person)  In-person  Remote
# 172                                           10          9      40
# 173                                           62        110      28
# 174                                            3          5       4
# 175                                            4          5       3
# 176                                            8          6       6

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
## Write your code here
df['YearsCodePro']= df['YearsCodePro'].replace({'Less than 1 year': 0, 'More than 50 years': 51})
Pearson_coeff= df['JobSat'].corr(df['YearsCodePro'], method= 'pearson')
print(f'Pearson coefficient is:{Pearson_coeff}')
# Out:
# Pearson coefficient is:0.10415320964659897

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
## Write your code here
df_subset=df.dropna(subset=['Employment' , 'EdLevel', 'ResponseId'])
pivot_table= df_subset.pivot_table(index='Employment', columns= 'EdLevel', values='ResponseId', aggfunc='size').dropna()

pivot_table.plot(kind='bar', stacked=True, figsize=(25,20))
plt.title('Cross-tabulation Analysis (Employment vs. Education Level)')
plt.xlabel('Employment')
plt.ylabel('Count')
plt.show()
# Out:
# EdLevel                                             Associate degree (A.A., A.S., etc.)  \
# Employment
# Employed, full-time                                                              1059.0
# Employed, full-time;Employed, part-time                                             9.0
# Employed, full-time;Independent contractor, fre...                                104.0
# Employed, full-time;Independent contractor, fre...                                 11.0
# Employed, full-time;Student, full-time                                             30.0
# Employed, full-time;Student, part-time                                             36.0
# Employed, part-time                                                                39.0
# I prefer not to say                                                                 9.0
# Independent contractor, freelancer, or self-emp...                                143.0
# ...

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
